# %% [markdown]
# <a href="https://colab.research.google.com/github/desalegn816/feedback/blob/main/ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
actual    = np.array(
  ['Dog','Dog','Dog','Not Dog','Dog','Not Dog','Dog','Dog','Not Dog','Not Dog'])
predicted = np.array(
  ['Dog','Not Dog','Dog','Not Dog','Dog','Dog','Dog','Dog','Not Dog','Not Dog'])
cm = confusion_matrix(actual, predicted)

# %%
sns.heatmap(cm,
            annot=True,
            fmt='g',
            xticklabels=['Dog','Not Dog'],
            yticklabels=['Dog','Not Dog'])
plt.ylabel('Actual', fontsize=13)
plt.title('Confusion Matrix', fontsize=17, pad=20)
plt.gca().xaxis.set_label_position('top')
plt.xlabel('Prediction', fontsize=13)
plt.gca().xaxis.tick_top()

plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)
plt.show()

# %%
print(cm)
print(plt.xlabel,plt.ylabel)
# Out:
# [[5 1]
#  [1 3]]
# <function xlabel at 0x7912faf3ade0> <function ylabel at 0x7912faf3ae80>

# %%
print(classification_report(actual, predicted))
# Out:
#               precision    recall  f1-score   support
#
#          Dog       0.83      0.83      0.83         6
#      Not Dog       0.75      0.75      0.75         4
#
#     accuracy                           0.80        10
#    macro avg       0.79      0.79      0.79        10
# weighted avg       0.80      0.80      0.80        10
